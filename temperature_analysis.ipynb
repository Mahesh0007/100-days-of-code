# %% [markdown]
# <a href="https://colab.research.google.com/github/Mahesh0007/100-days-of-code/blob/master/temperature_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

temps_celsius = np.array([22, 25, 28, 24, 26])
temps_fahrenheit = temps_celsius * 1.8 + 32

print("Celsius:", temps_celsius)
print("Fahrenheit:", temps_fahrenheit)
print("Average Fahrenheit:", round(np.mean(temps_fahrenheit), 1))
# Out:
# Celsius: [22 25 28 24 26]
# Fahrenheit: [71.6 77.  82.4 75.2 78.8]
# Average Fahrenheit: 77.0

# %%
import numpy as np

scores = np.array([85, 90, 78, 92, 88, 76, 95, 82, 89, 91, 87, 84])

print("Shape:", scores.shape)
print("Total elements:", scores.size)
print("Highest score:", np.max(scores))
print("Lowest score:", np.min(scores))
print("Range:", np.max(scores) - np.min(scores))
# Out:
# Shape: (12,)
# Total elements: 12
# Highest score: 95
# Lowest score: 76
# Range: 19

# %%
import numpy as np
import time

numpy_arr = np.arange(1, 50001)
python_list = list(range(1, 50001))

start = time.time()
numpy_sum = np.sum(numpy_arr)
numpy_time = time.time() - start

start = time.time()
python_sum = sum(python_list)
python_time = time.time() - start

print(f"NumPy sum: {numpy_sum}")
print(f"Python sum: {python_sum}")
print(f"NumPy time: {numpy_time:.4f} seconds")
print(f"Python time: {python_time:.4f} seconds")
print(f"NumPy is {round(python_time / numpy_time, 1)}x faster")
# Out:
# NumPy sum: 1250025000
# Python sum: 1250025000
# NumPy time: 0.0006 seconds
# Python time: 0.0006 seconds
# NumPy is 1.0x faster
